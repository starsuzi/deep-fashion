# %%
import pandas as pd
import csv
import numpy as np
import matplotlib.pyplot as plt

# %%
df_final= pd.read_csv('./name_merged.csv')
df_merged_more = pd.read_csv('./Anno/changed/etri/merged_more.csv')

# %%
more_frequency = (df_merged_more.iloc[:,3:] == 1).sum(axis=0)
more_frequency_sort=more_frequency.sort_values(ascending = False)
print(more_frequency_sort[:])
# Out:
# woman           79992
# others          39661
# long            24307
# floral          22929
# striped         18422
# no sleeves      11575
# long sleeves     7095
# summer           5781
# red              5575
# pink             5346
# dotted           3981
# short            3234
# winter            676
# checker           616
# dtype: int64

# %%
frequency = (df_final.iloc[:,3:] == 1).sum(axis=0)
frequency_sort=frequency.sort_values(ascending = False)
print(frequency_sort[:])
# Out:
# woman            79992
# others           46984
# floral           27939
# long             24456
# striped          22758
# no sleeves       12749
# long sleeves      7107
# summer            5781
# red               5575
# pink              5346
# dotted            5009
# short             3234
# checker           1244
# winter             676
# short sleeves       67
# dtype: int64

# %%
more_frequency_sort[:].plot(kind = 'bar', figsize=(15,5), fontsize = 15)
plt.title("attributes histrogram")
plt.xlabel("attributes")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
frequency_sort[:].plot(kind = 'bar', figsize=(15,5), fontsize = 15)
plt.title("attributes histrogram")
plt.xlabel("attributes")
plt.ylabel("count")
# Out:
# Text(0, 0.5, 'count')

# %%
lst = []
for i, img in enumerate(lst_img):
   # print(img)
    if '&' in img:
        print(img)
        lst.append(img)

# %%
from os import rename, listdir

def replaceNpercent(path):
    fnames = listdir(path)

    for fname in fnames:
        if '&'in fname:
            #print(fname)
            rename(path+fname, path+fname.replace('&', 'and'))
            print(fname)

# %%
replaceNpercent('./asdf/')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-8-603899d056ef> in <module>
# ----> 1 replaceNpercent('./asdf/')
#
# <ipython-input-6-216caf47bdfe> in replaceNpercent(path)
#       2
#       3 def replaceNpercent(path):
# ----> 4     fnames = listdir(path)
#       5
#       6     for fname in fnames:
#
# FileNotFoundError: [WinError 3] 지정된 경로를 찾을 수 없습니다: './asdf/'

# %%
replaceNpercent('./jacket/')
# Out:
# Boucl&eacute;_Knit_Cardigan_img_00000001.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000002.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000003.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000004.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000005.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000006.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000007.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000008.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000009.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000010.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000011.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000012.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000013.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000014.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000015.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000016.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000017.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000018.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000019.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000020.jpg
# Boucl&eacute;_Knit_Cardigan_img_00000021.jpg
# ...

# %%
replaceNpercent('./pants/')
# Out:
# Cotton_&_Linen_Pleated_Shorts_desktop.ini
# Cotton_&_Linen_Pleated_Shorts_img_00000001.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000002.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000003.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000004.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000005.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000006.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000007.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000008.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000009.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000010.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000011.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000012.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000013.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000014.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000015.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000016.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000017.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000018.jpg
# Cotton_&_Linen_Pleated_Shorts_img_00000019.jpg
# ...

# %%
replaceNpercent('./skirt/')
# Out:
# Chenille_&_Metallic_Knit_Skirt_img_00000001.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000002.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000003.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000004.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000005.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000006.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000007.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000008.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000009.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000010.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000011.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000012.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000013.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000014.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000015.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000016.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000017.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000018.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000019.jpg
# Chenille_&_Metallic_Knit_Skirt_img_00000020.jpg
# ...

# %%
replaceNpercent('./dress/')
# Out:
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000001.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000002.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000003.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000004.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000005.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000006.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000007.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000008.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000009.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000010.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000011.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000012.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000013.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000014.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000015.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000016.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000017.jpg
# Abstract_Paisley_Fit_&_Flare_Dress_img_00000018.jpg
# ...

# %%
replaceNpercent('./jumper/')

# %%
replaceNpercent('./winter jacket/')

# %%
replaceNpercent('./shirt/')
# Out:
# Beauty_&_Brains_Muscle_Tee_img_00000001.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000002.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000003.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000004.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000005.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000006.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000007.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000008.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000009.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000010.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000011.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000012.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000013.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000014.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000015.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000016.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000017.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000018.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000019.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000020.jpg
# Beauty_&_Brains_Muscle_Tee_img_00000021.jpg
# ...

# %%
replaceNpercent('./coat/')
# Out:
# Two-Tone_Boucl&eacute;_Coat_img_00000001.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000002.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000003.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000004.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000005.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000006.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000007.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000008.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000009.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000010.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000011.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000012.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000013.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000014.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000015.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000016.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000017.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000018.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000019.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000020.jpg
# Two-Tone_Boucl&eacute;_Coat_img_00000021.jpg
# ...

# %%
import os

dir_name = "./pants/"
test = os.listdir(dir_name)

for item in test:
    if item.endswith(".xml"):
        os.remove(os.path.join(dir_name, item))

# %%
dir_name = "./dress/"
test = os.listdir(dir_name)

for item in test:
    if item.endswith(".xml"):
        os.remove(os.path.join(dir_name, item))

# %%
dir_name = "./shirt/"
test = os.listdir(dir_name)

for item in test:
    if item.endswith(".xml"):
        os.remove(os.path.join(dir_name, item))

# %%
dir_name = "./jacket/"
test = os.listdir(dir_name)

for item in test:
    if item.endswith(".xml"):
        os.remove(os.path.join(dir_name, item))

# %%
dir_name = "./jumper/"
test = os.listdir(dir_name)

for item in test:
    if item.endswith(".xml"):
        os.remove(os.path.join(dir_name, item))

# %%
dir_name = "./skirt/"
test = os.listdir(dir_name)

for item in test:
    if item.endswith(".xml"):
        os.remove(os.path.join(dir_name, item))

# %%
dir_name = "./coat/"
test = os.listdir(dir_name)

for item in test:
    if item.endswith(".xml"):
        os.remove(os.path.join(dir_name, item))

# %%
dir_name = "./winter jacket/"
test = os.listdir(dir_name)

for item in test:
    if item.endswith(".xml"):
        os.remove(os.path.join(dir_name, item))
